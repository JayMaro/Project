# %%
import os
import numpy
from glob import glob 
from music21 import converter, instrument, note, chord, stream
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Input, Dense, LSTM, GRU
from tensorflow.keras.layers import BatchNormalization as BatchNorm

from tensorflow.keras.layers import Bidirectional, TimeDistributed



import tensorflow as tf
import random

# %%
notes = []

# %%
from tqdm.notebook import tqdm

# %%
os.listdir('songs')
# Out:
# ['HighwindTakestotheSkies.mid',
#  'Kingdom_Hearts_Dearly_Beloved.mid',
#  'Kingdom_Hearts_Traverse_Town.mid']

# %%
for file in tqdm(glob('songs/*.mid')):
    midi = converter.parse(file)
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts:
        notes_to_parse = parts.parts[0].recurse()
    else: 
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
n_vocab = len(set(notes))

# %%
sequence_length = 50
pitchnames = sorted(set(item for item in notes))

note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
network_input = []
network_output = []

for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])

n_patterns = len(network_input)

network_input = numpy.reshape(network_input, (n_patterns, sequence_length, 1))

network_input = network_input / float(n_vocab)
network_output = to_categorical(network_output)

# %%
network_output.shape
# Out:
# (1900, 113)

# %%
network_input.shape
# Out:
# (1900, 50, 1)

# %%
model = Sequential()
model.add(GRU(
        512,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        return_sequences=True
    ))
model.add(Dropout(0.3))
model.add(GRU(512, return_sequences=True))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(GRU(512))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(n_vocab))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"    
checkpoint = tf.keras.callbacks.ModelCheckpoint(
            filepath, monitor='loss',
            verbose=0,        
            save_best_only=True,        
            mode='min'
        )    
callbacks_list = [checkpoint]     
model.fit(network_input, network_output, epochs=100, batch_size = 64, callbacks=callbacks_list,shuffle=100)
# Out:
# Train on 1900 samples
# Epoch 1/100
# 1900/1900 [==============================] - 10s 5ms/sample - loss: 4.6259 - accuracy: 0.0642
# Epoch 2/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 4.0849 - accuracy: 0.1084
# Epoch 3/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 3.8518 - accuracy: 0.1300
# Epoch 4/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 3.5402 - accuracy: 0.1505
# Epoch 5/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 3.2910 - accuracy: 0.1926
# Epoch 6/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 3.1005 - accuracy: 0.2232
# Epoch 7/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 2.8004 - accuracy: 0.2874
# Epoch 8/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 2.5863 - accuracy: 0.3232
# Epoch 9/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 2.3905 - accuracy: 0.3679
# Epoch 10/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 2.1770 - accuracy: 0.4226
# Epoch 11/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 2.0201 - accuracy: 0.4574
# Epoch 12/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.8345 - accuracy: 0.5100
# Epoch 13/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.6641 - accuracy: 0.5353
# Epoch 14/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.5183 - accuracy: 0.5937
# Epoch 15/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.3758 - accuracy: 0.6295
# Epoch 16/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.2195 - accuracy: 0.6779
# Epoch 17/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.0943 - accuracy: 0.7189
# Epoch 18/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 1.0071 - accuracy: 0.7353
# Epoch 19/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.9217 - accuracy: 0.7584
# Epoch 20/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.8212 - accuracy: 0.7863
# Epoch 21/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.7572 - accuracy: 0.7932
# Epoch 22/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.6958 - accuracy: 0.8221
# Epoch 23/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.6348 - accuracy: 0.8284
# Epoch 24/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.6117 - accuracy: 0.8353
# Epoch 25/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.5882 - accuracy: 0.8337
# Epoch 26/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.5530 - accuracy: 0.8542
# Epoch 27/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4794 - accuracy: 0.8689
# Epoch 28/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4807 - accuracy: 0.8658
# Epoch 29/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4343 - accuracy: 0.8795
# Epoch 30/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4220 - accuracy: 0.8789
# Epoch 31/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4346 - accuracy: 0.8779
# Epoch 32/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4060 - accuracy: 0.8821
# Epoch 33/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3435 - accuracy: 0.9005
# Epoch 34/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3568 - accuracy: 0.8947
# Epoch 35/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3425 - accuracy: 0.9005
# Epoch 36/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3502 - accuracy: 0.8989
# Epoch 37/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3419 - accuracy: 0.9105
# Epoch 38/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3005 - accuracy: 0.9053
# Epoch 39/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.3154 - accuracy: 0.9095
# Epoch 40/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2966 - accuracy: 0.9074
# Epoch 41/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2649 - accuracy: 0.9200
# Epoch 42/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2442 - accuracy: 0.9263
# Epoch 43/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2413 - accuracy: 0.9289
# Epoch 44/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2439 - accuracy: 0.9274
# Epoch 45/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2128 - accuracy: 0.9374
# Epoch 46/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2363 - accuracy: 0.9274
# Epoch 47/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1979 - accuracy: 0.9432
# Epoch 48/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2087 - accuracy: 0.9374
# Epoch 49/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1952 - accuracy: 0.9316
# Epoch 50/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2017 - accuracy: 0.9400
# Epoch 51/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1866 - accuracy: 0.9453
# Epoch 52/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1623 - accuracy: 0.9463
# Epoch 53/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1835 - accuracy: 0.9442
# Epoch 54/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2091 - accuracy: 0.9342
# Epoch 55/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1759 - accuracy: 0.9479
# Epoch 56/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1743 - accuracy: 0.9484
# Epoch 57/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1699 - accuracy: 0.9484
# Epoch 58/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1797 - accuracy: 0.9521
# Epoch 59/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1729 - accuracy: 0.9495
# Epoch 60/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1656 - accuracy: 0.9505
# Epoch 61/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1370 - accuracy: 0.9621
# Epoch 62/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1317 - accuracy: 0.9653
# Epoch 63/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1124 - accuracy: 0.9668
# Epoch 64/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1114 - accuracy: 0.9647
# Epoch 65/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.6408 - accuracy: 0.8363
# Epoch 66/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.4740 - accuracy: 0.8568
# Epoch 67/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.2910 - accuracy: 0.9084
# Epoch 68/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1985 - accuracy: 0.9389
# Epoch 69/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1750 - accuracy: 0.9474
# Epoch 70/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1539 - accuracy: 0.9505
# Epoch 71/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1403 - accuracy: 0.9563
# Epoch 72/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1160 - accuracy: 0.9647
# Epoch 73/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1165 - accuracy: 0.9668
# Epoch 74/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1006 - accuracy: 0.9711
# Epoch 75/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1195 - accuracy: 0.9616
# Epoch 76/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1097 - accuracy: 0.9679
# Epoch 77/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.1002 - accuracy: 0.9705
# Epoch 78/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0848 - accuracy: 0.9753
# Epoch 79/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0848 - accuracy: 0.9705
# Epoch 80/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0713 - accuracy: 0.9763
# Epoch 81/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0904 - accuracy: 0.9695
# Epoch 82/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0754 - accuracy: 0.9768
# Epoch 83/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0815 - accuracy: 0.9758
# Epoch 84/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0779 - accuracy: 0.9800
# Epoch 85/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0723 - accuracy: 0.9774
# Epoch 86/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0650 - accuracy: 0.9805
# Epoch 87/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0557 - accuracy: 0.9853
# Epoch 88/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0586 - accuracy: 0.9842
# Epoch 89/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0775 - accuracy: 0.9768
# Epoch 90/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0711 - accuracy: 0.9816
# Epoch 91/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0639 - accuracy: 0.9837
# Epoch 92/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0511 - accuracy: 0.9853
# Epoch 93/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0392 - accuracy: 0.9916
# Epoch 94/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0379 - accuracy: 0.9853
# Epoch 95/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0458 - accuracy: 0.9868
# Epoch 96/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0521 - accuracy: 0.9889
# Epoch 97/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0681 - accuracy: 0.9811
# Epoch 98/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0808 - accuracy: 0.9753
# Epoch 99/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0865 - accuracy: 0.9726
# Epoch 100/100
# 1900/1900 [==============================] - 4s 2ms/sample - loss: 0.0802 - accuracy: 0.9774

# %%
start = numpy.random.randint(0, len(network_input)-1)

int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
pattern = network_input[start]

prediction_output = []

# %%
prediction_input = numpy.reshape(pattern, (1, len(pattern), 1))
prediction_input = prediction_input/float(n_vocab)
prediction = model.predict(prediction_input, verbose=0)
prediction.shape
# Out:
# (1, 113)

# %%
for note_index in range(800):
    prediction_input = numpy.reshape(pattern, (1, len(pattern), 1))
    prediction_input = prediction_input / float(n_vocab)

    prediction = model.predict(prediction_input, verbose=0)
    index = numpy.argmax(prediction)
    print(index)
    
    result = int_to_note[index]
    prediction_output.append(result)
    pattern = numpy.append(pattern, index)[:,numpy.newaxis]
    pattern = pattern[1:len(pattern)]
# Out:
# 54
# 54
# 7
# 54
# 54
# 7
# 7
# 7
# 46
# 17
# 46
# 41
# 50
# 47
# 47
# 28
# 49
# 49
# 4
# 4
# 29
# 29
# 9
# 28
# 32
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 29
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 67
# 70
# 20
# 91
# 70
# 67
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38
# 100
# 70
# 74
# 62
# 74
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 29
# 58
# 67
# 53
# 91
# 70
# 20
# 67
# 70
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 62
# 70
# 85
# 70
# 62
# 70
# 20
# 95
# 91
# 70
# 62
# 70
# 91
# 70
# 62
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38
# 100
# 70
# 74
# 62
# 74
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 29
# 58
# 67
# 53
# 91
# 70
# 20
# 67
# 70
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 62
# 70
# 85
# 70
# 62
# 70
# 20
# 95
# 91
# 70
# 62
# 70
# 91
# 70
# 62
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38
# 100
# 70
# 74
# 62
# 74
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 29
# 58
# 67
# 53
# 91
# 70
# 20
# 67
# 70
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 62
# 70
# 85
# 70
# 62
# 70
# 20
# 95
# 91
# 70
# 62
# 70
# 91
# 70
# 62
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38
# 100
# 70
# 74
# 62
# 74
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 29
# 58
# 67
# 53
# 91
# 70
# 20
# 67
# 70
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 62
# 70
# 85
# 70
# 62
# 70
# 20
# 95
# 91
# 70
# 62
# 70
# 91
# 70
# 62
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38
# 100
# 70
# 74
# 62
# 74
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 29
# 58
# 67
# 53
# 91
# 70
# 20
# 67
# 70
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 53
# 95
# 85
# 70
# 62
# 70
# 85
# 70
# 62
# 70
# 20
# 95
# 91
# 70
# 62
# 70
# 91
# 70
# 62
# 70
# 9
# 5
# 71
# 75
# 63
# 75
# 32
# 29
# 8
# 8
# 2
# 2
# 71
# 12
# 75
# 63
# 75
# 12
# 1
# 71
# 13
# 75
# 63
# 75
# 71
# 8
# 75
# 63
# 75
# 9
# 70
# 74
# 62
# 74
# 32
# 70
# 74
# 62
# 74
# 8
# 70
# 74
# 62
# 74
# 34
# 90
# 70
# 67
# 58
# 67
# 70
# 67
# 58
# 67
# 29
# 95
# 85
# 70
# 67
# 70
# 53
# 91
# 70
# 20
# 67
# 70
# 38

# %%
offset = 0
output_notes = []
for pattern in prediction_output:
    if ('.' in pattern) or pattern.isdigit():
        notes_in_chord = pattern.split('.')
        notes = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note.storedInstrument = instrument.Piano()
            notes.append(new_note)
        new_chord = chord.Chord(notes)
        new_chord.offset = offset
        output_notes.append(new_chord)
    else:
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)

    offset += 0.5

# %%
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='test_output.mid')
# Out:
# 'test_output.mid'
